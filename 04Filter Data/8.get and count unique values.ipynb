# %%
import pandas as pd

df = pd.read_csv('laptop_price.csv',encoding='unicode_escape')

# %% [markdown]
# 1 unique()
# Return unique values of series object . (Uniques are returned in order of appearance)

# %%
#get unique elements in ""Company" column/series
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
#get unique elements in Inches column/series
df['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
len(df['Company'].unique())
# Out:
# 19

# %% [markdown]
# 2. nunique()
# Retuen number of unique elements in object (excluding NA values by default)

# %%
#get number of unique emelents in compnay col
df['Company'].nunique()
# Out:
# 19

# %%
#get number of unique emelents in inches col
df['Inches'].nunique()
# Out:
# 18
