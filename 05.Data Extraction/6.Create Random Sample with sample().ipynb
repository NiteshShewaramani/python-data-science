# %%
import pandas as pd

#read csv file
df = pd.read_csv('players_20.csv' , encoding = 'unicode_escape')

#set index
#df = df.set_index('short_name') #creates a copy so we need to overwrite  
df.set_index('short_name',inplace=True)

#select columns
df = df[['long_name',	'age',	'dob',	'height_cm',	'weight_kg',	'nationality',	'club']]

#show dataframe
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi               Lionel AndrÃ©s Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                      éµå¸
#    22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                       å¼ å¨   19  2000-05-16
# Wang Haijian                                 æ±ªæµ·å¥   18  2000-08-02
# Pan Ximing                                   æ½åæ   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# 1 sample()

# %%
#extract 10 random elements from the "nationality" col

df['nationality'].sample(10)
# Out:
# short_name
# Nathan                       Brazil
# T. ChorÃ½            Czech Republic
# Porphirinho                  Brazil
# A. Al Yami             Saudi Arabia
# A. Weis                     Germany
# D. Mihailovic         United States
# E. Aguirre                   Mexico
# J. Jones                    England
# Claude GonÃ§alves          Portugal
# Guo Quanbo                 China PR
# Name: nationality, dtype: object

# %%
#extract a random 20% sample of the dataframe
df.sample(frac=0.2)
# Out:
#                                       long_name  age         dob  height_cm  \
# short_name
# Camacho                 Ignacio Camacho Barnola   29  1990-05-04        183
# G. MacKenzie                     Gary MacKenzie   33  1985-10-15        191
# M. Klich                          Mateusz Klich   29  1990-06-13        183
# J. MartÃ­nez   JosÃ© JoaquÃ­n MartÃ­nez Valadez   32  1987-02-22        177
# D. Chambost                      Dylan Chambost   21  1997-08-19        177
# ...                                         ...  ...         ...        ...
# C. DÃ­az                           Camilo DÃ­az   21  1997-08-02        182
# Park Sung Min           ë°ì±ë¯¼ Sung Min Park   20  1998-12-12        181
# M. Cestor                           Mike Cestor   27  1992-04-30        178
# Carlos ManÃ©        Carlos Manuel Cardoso ManÃ©   25  1994-03-11        173
# Rafa Tresaco              Rafael Tresaco Blasco   18  2000-08-24        178
#
# ...

# %%
#upsample increase the sampling rate frac>1 (Note replace param has to be true) 
df.sample(frac=2, replace=True)
# Out:
#                                            long_name  age         dob  \
# short_name
# Han Seok Hee                             SeokHee Han   23  1996-05-16
# R. SÃ¡nchez                         Richard SÃ¡nchez   23  1996-03-29
# C. Zesiger                           CÃ©dric Zesiger   21  1998-06-24
# F. Cerda               FabiÃ¡n Alfredo Cerda ValdÃ©s   30  1989-02-07
# R. Ofosu                                 Reagy Ofosu   27  1991-09-20
# ...                                              ...  ...         ...
# Tano Bonnin     Cayetano BartolomÃ© BonnÃ­n VÃ¡squez   29  1990-06-30
# O. Malik                                 Osama Malik   28  1990-09-30
# P. Pentz                               Patrick Pentz   22  1997-01-02
# L. Galicia                              Luis Galicia   19  2000-04-12
# Rafael Defendi        Rafael  Garcia Tonioli Defendi   35  1983-12-22
#
#                 height_cm  weight_kg         nationality  \
# short_name
# ...
